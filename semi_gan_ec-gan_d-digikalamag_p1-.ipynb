# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/digikalamag/blob/main/semi_gan_ec-gan_d-digikalamag_p1-.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.02
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d digikalamag -p 0.01
# Out:
# Streaming output truncated to the last 5000 lines.
# 34     35  81.103286
# 35     36  84.272300
# 718 / 852 * 100 = 84.27230046948357
#
# ======== Epoch 37 / 100 ========
# Training...
# ./semi_supervised_learning_with_gan/ecgan_parsbert.py:348: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = self.softmax(logits)
# Epoch 37 Complete
#     epoch        acc
# 0       1  32.511737
# 1       2  32.511737
# 2       3  32.511737
# 3       4  32.511737
# 4       5  32.511737
# 5       6  32.511737
# 6       7  32.511737
# 7       8  32.511737
# 8       9  50.469484
# 9      10  47.065728
# 10     11  69.131455
# 11     12  69.483568
# 12     13  68.896714
# 13     14  70.657277
# 14     15  78.051643
# 15     16  78.169014
# 16     17  80.633803
# 17     18  81.338028
# 18     19  82.629108
# 19     20  83.215962
# 20     21  82.863850
# 21     22  83.098592
# 22     23  82.981221
# 23     24  82.863850
# ...
